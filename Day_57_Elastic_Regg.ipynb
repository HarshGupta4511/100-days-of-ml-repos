# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
X,y = load_diabetes(return_X_y=True)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
rdg = Ridge(alpha = 0.3 )

# %%
rdg.fit(X_train,y_train)
y_pred = rdg.predict(X_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.45119897496622097

# %%
ls = Lasso(alpha = 0.01 , max_iter=60)

# %%
ls.fit(X_train,y_train)
y_pred = ls.predict(X_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.44131782677499
# C:\Users\Harshgupta\anaconda3\envs\harsenv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.097e+04, tolerance: 2.124e+02
#   model = cd_fast.enet_coordinate_descent(

# %%
en = ElasticNet(alpha=0.007,l1_ratio = 0.9)

# %%
en.fit(X_train,y_train)
y_pred = en.predict(X_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.4520377663040388
